# %% [markdown]
# # Data Science Fundamentals
# ## Lesson 1 — Introduction
#
# Congratulations on installing Python and JupyterLab! To confirm your setup is working, run the cells below.
# We'll first install a few commonly used data science libraries.

# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now import the libraries you just installed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Preview the dataset by displaying the first rows.

# %%
blobs = pd.read_csv('./DSF 01 - Intro Data.csv')
blobs.head()
# Out:
#          X1        X2
# 0  4.645333  6.822294
# 1  4.784032  6.422883
# 2 -5.851786  5.774331
# 3 -7.459592  6.456415
# 4  4.918911  6.961479

# %% [markdown]
# As a final check, create a quick scatter plot to visualize the data.

# %%
sns.scatterplot(data=blobs,x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>
