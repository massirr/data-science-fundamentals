# %% [markdown]
# ## Section 0: Setup
#
# Personalization and package imports.

# %%
# PERSONALIZATION CELL - RUN THIS FIRST!
import sys
sys.path.append('.')
from student_assignment import generate_assignment, print_assignment_details

STUDENT_ID = 'r1012152'  # ← Change this to your student ID / r1111111

# Get assignment details and display them
assignment_params = print_assignment_details(STUDENT_ID)

# Extract key variables for use throughout the notebook
DATASET = assignment_params['dataset']
FEATURES = assignment_params['required_features']
TARGET = assignment_params['TARGET']
# Out:
# Assignment for r1012152:
# Dataset: california_housing.csv
#
# Dataset Description:
# California Housing Dataset - This dataset contains information about housing in California districts from the 1990 census. The goal is to predict the median house value based on various demographic and geographic features.
#
# Target: median_house_value - Median house value in California districts (in hundreds of thousands of dollars)
#
# Required features:
#   - longitude: Longitude coordinate of the district
#   - latitude: Latitude coordinate of the district
#   - housing_median_age: Median age of houses in the district
#   - total_rooms: Total number of rooms in the district
#
# Task type:
# -regression
# Task description:
# -Predict median house values in California districts
# Use different regression models to compare performance.

# %%
# Standard imports following course conventions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Model selection and evaluation
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

# %% [markdown]
# ## Section 1: Data Loading and Exploration (20 points)
#
# Load your assigned dataset and perform comprehensive exploration to understand the data structure, distributions, and relationships.

# %%
# Load dataset
df = pd.read_csv(f'datasets/{DATASET}')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### 1.1 Basic Dataset Information

# %%
# Display dataset shape
print(f"Dataset shape: {df.shape}")
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# %%
# Display data types and non-null counts
df.info()

# %%
# Display summary statistics
df.describe()

# %% [markdown]
# ### 1.2 Missing Values Analysis

# %%
# Check for missing values
print("Missing values per column:")
print(df.isnull().sum())
print(f"\nTotal missing values: {df.isnull().sum().sum()}")
print(f"Percentage of missing values: {(df.isnull().sum().sum() / (df.shape[0] * df.shape[1]) * 100):.2f}%")

# %% [markdown]
# ### 1.3 Feature Distributions
#
# Let's visualize the distributions of key features to understand the data better.

# %%
# Visualize distributions of required features
# TODO: Run personalization cell first to see which features to focus on
# You can create histograms or box plots for your required features

# %% [markdown]
# ### 1.4 Outlier Detection
#
# Check for outliers that might affect model performance.

# %%
# Create box plots to identify outliers
# TODO: Focus on your required features

# %% [markdown]
# ### 1.5 Feature Relationships
#
# Explore relationships between features and the target variable.

# %%
# Correlation analysis or scatter plots
# TODO: Analyze how your required features relate to the target

# %% [markdown]
# ## Section 2: Data Processing (25 points)
#
# Clean, preprocess, and engineer features for your dataset. Handle missing values, outliers, and prepare data for modeling.

# %%
# Your code here - use your assigned FEATURES

# %% [markdown]
# ## Section 3: Model Building (30 points)
#
# Select appropriate models for your task type, implement hyperparameter tuning, and compare different approaches.

# %%
# Your code here - model selection, training, and hyperparameter tuning

# %% [markdown]
# ## Section 4: Evaluation (25 points)
#
# Evaluate your models comprehensively and interpret the results.

# %%
# Your code here
